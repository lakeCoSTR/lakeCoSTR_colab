# %% [markdown]
# <a href="https://colab.research.google.com/github/steeleb/lakeCoSTR_colab/blob/dev/lakeCoSTRv1_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **lakeCoSTR for Colab**<br>
# a tool for *__lake__ __Co__ llection 2 __S__ urface __T__ emperature __R__ etrieval*<p>
# <p>
#
# **Version 1.12**<br>
# *Last updated: 2022-09-06<p>*
#
# Created by:<br>
# Christina Herrick<br>
# University of New Hampshire<br>
# christina.herrick@unh.edu<p>
# Bethel Steele<br>
# Cary Institute of Ecosystem Studies<br>
# steeleb@caryinstitute.org<p>
# __This tool is still under development and has an associated manuscript that has been submitted for peer review. This tool is licensed under CC-BY-NC-SA, please cite accordingly.__

# %% [markdown]
# # **User Guide**
# Please review the [**user guide**](https://github.com/lakeCoSTR/lakeCoSTR_colab/blob/main/UserGuide_lakeCoSTR_colab.md) for assistance in navigating the tool and for specific constraints and caveats.
#
# # **Motivations of lakeCoSTR**
# We created lakeCoSTR to make the acquisition and analysis of Landsat's Collection 2 Surface Temperature product more accessible for those interested in obtaining historical estimates of lake temperature from remote sensing data. This tool is geared to researchers interested in gathering historical temperature estimates, especially for small lakes.

# %% [markdown]
# # **1. Initial Setup**

# %% [markdown]
# ## **1.1 Modules**
#
# This section of code blocks imports necessary python modules for the notebook to run. You will be prompted to click one or more URLs and be taken to a page to sign in with your Google account.
#
# Copy the unique code(s) provided on the web page when prompted and paste where prompted to finish authorization.

# %%
#@markdown __Run this block__ to authorize Colab to authenticate your Google account and give it access to upload files from your local computer.
from google.colab import auth, files
auth.authenticate_user()
import gspread
from oauth2client.client import GoogleCredentials

# %%
#@markdown __Run this block__ to connect Colab to your Earth Engine account
#@markdown You must already be authorized to use Google Earth Engine. 
#@markdown <p>If you do not already have access, <a href="https://signup.earthengine.google.com/#!/" target="_blank">fill out this application</a>.
import ee
ee.Authenticate()
ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=ArLCxADopvmXcmgTSLU2k2NlHvKn-5q6qYZQXohwaXY&tc=lcorlq8VUktxIzR69nGqbsWkJcdncEbSIK1aQB_XOk4&cc=cN0HOJaepG0zYDG7_2WKmU9iNGL1x65-AsrpvUSPBB8
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1AdQt8qj90ZaSL0sK5_D2nk2DUq7c3nEkBcgU8XlhpyvRD90xQW4Pkm--6YU
#
# Successfully saved authorization token.

# %%
#@markdown __Run this block__ to connect Colab to your Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
#@markdown __Run this block__ to install packages and functions used for 
#@markdown interactive mapping and data exploration
import pandas as pd
import numpy as np
import os
import re
import subprocess
import matplotlib.pyplot as plt
from time import strftime, sleep
from datetime import datetime, timedelta
import pytz
import folium
from folium import plugins
from google.colab import data_table

try:
  from ipyleaflet import Map, DrawControl
  from ipywidgets import Layout
except ImportError:
  subprocess.check_call(["python","-m","pip","install","-U","ipyleaflet"])
  from ipyleaflet import Map, basemaps, basemap_to_tiles, DrawControl
  from ipywidgets import Layout

# Add custom basemaps to folium
basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )
}

# Define a method for displaying Earth Engine image tiles on a folium map.
def add_ee_layer(self, ee_object, vis_params, name):
    
    try:    
        # display ee.Image()
        if isinstance(ee_object, ee.image.Image):    
            map_id_dict = ee.Image(ee_object).getMapId(vis_params)
            folium.raster_layers.TileLayer(
            tiles = map_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = name,
            overlay = True,
            control = True
            ).add_to(self)
        # display ee.ImageCollection()
        elif isinstance(ee_object, ee.imagecollection.ImageCollection):    
            ee_object_new = ee_object.mosaic()
            map_id_dict = ee.Image(ee_object_new).getMapId(vis_params)
            folium.raster_layers.TileLayer(
            tiles = map_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = name,
            overlay = True,
            control = True
            ).add_to(self)
        # display ee.Geometry()
        elif isinstance(ee_object, ee.geometry.Geometry):    
            folium.GeoJson(
            data = ee_object.getInfo(),
            name = name,
            overlay = True,
            control = True
        ).add_to(self)
        # display ee.FeatureCollection()
        elif isinstance(ee_object, ee.featurecollection.FeatureCollection):  
            ee_object_new = ee.Image().paint(ee_object, 0, 2)
            map_id_dict = ee.Image(ee_object_new).getMapId(vis_params)
            folium.raster_layers.TileLayer(
            tiles = map_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = name,
            overlay = True,
            control = True
        ).add_to(self)
    
    except:
        print("Could not display {}".format(name))
    
# Add EE drawing method to folium.
folium.Map.add_ee_layer = add_ee_layer

print("Packages installed")
# Out:
# Packages installed

# %% [markdown]
# ## **1.2 Imported variables**
# These are Landsat-specific variable settings for GEE.

# %%
#@markdown __Run this block__ to import pre-existing features, images, and collections from Earth Engine
wrs2 = ee.FeatureCollection("users/christinaherrickunh/WRS2_descending_2018")
utmbounds = ee.FeatureCollection("users/christinaherrickunh/UTM_Zone_Boundaries")
sw = ee.Image("JRC/GSW1_2/GlobalSurfaceWater")
openwater = sw.select("occurrence")
l4t1 = ee.ImageCollection("LANDSAT/LT04/C02/T1_L2")
l4t2 = ee.ImageCollection("LANDSAT/LT04/C02/T2_L2")
l5t1 = ee.ImageCollection("LANDSAT/LT05/C02/T1_L2")
l5t2 = ee.ImageCollection("LANDSAT/LT05/C02/T2_L2")
l7t1 = ee.ImageCollection("LANDSAT/LE07/C02/T1_L2")
l7t2 = ee.ImageCollection("LANDSAT/LE07/C02/T2_L2")
l8t1 = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
l8t2 = ee.ImageCollection("LANDSAT/LC08/C02/T2_L2")


def prep457bands(img):
  systime = img.get('system:time_start')
  elev = img.get("SUN_ELEVATION")
  sza = ee.Number(90).subtract(elev)
  
  qa = img.select(["QA_PIXEL"])
  cloud1 = qa.bitwiseAnd(2).eq(0)  # bit 1, dilated cloud
  cloud3 = qa.bitwiseAnd(8).eq(0)  # bit 3, cloud
  cloudshadow = qa.bitwiseAnd(16).eq(0) # bit 4, cloud shadow
  snow = qa.bitwiseAnd(32).eq(0)  # bit 5, snow
  cloud_confid = qa.rightShift(8).bitwiseAnd(3).lt(2)  # bits 8-9
  cloudsh_confid = qa.rightShift(10).bitwiseAnd(3).lt(2)  # bits 10-11
  snow_confid = qa.rightShift(12).bitwiseAnd(3).lt(2)  # bits 12-13
  cirrus_confid = qa.rightShift(14).bitwiseAnd(3).lt(2)  # bits 14-15

  temp = img.select(["ST_B6"],["surface_temp"]).multiply(0.00341802).add(149).add(-273.15)
  
  updated = (temp.updateMask(cloud1)
  .updateMask(cloud3)
  .updateMask(snow)
  .updateMask(cloudshadow)
  .updateMask(cloud_confid)
  .updateMask(snow_confid)
  .updateMask(cirrus_confid)
  .updateMask(cloudsh_confid))
          
  return ee.Image(updated).copyProperties(img).set("system:time_start",systime).set("SOLAR_ZENITH_ANGLE", sza)

def prep8bands(img):
  systime = img.get('system:time_start')
  elev = img.get("SUN_ELEVATION")
  sza = ee.Number(90).subtract(elev)

  qa = img.select(["QA_PIXEL"])
  cloud1 = qa.bitwiseAnd(2).eq(0)  # bit 1, dilated cloud
  cloud2 = qa.bitwiseAnd(4).eq(0)  # bit 2, cirrus (high confidence)
  cloud3 = qa.bitwiseAnd(8).eq(0)  # bit 3, cloud
  cloudshadow = qa.bitwiseAnd(16).eq(0) # bit 4, cloud shadow
  snow = qa.bitwiseAnd(32).eq(0)  # bit 5, snow
  cloud_confid = qa.rightShift(8).bitwiseAnd(3).lt(2)  # bits 8-9
  cloudsh_confid = qa.rightShift(10).bitwiseAnd(3).lt(2)  # bits 10-11
  snow_confid = qa.rightShift(12).bitwiseAnd(3).lt(2)  # bits 12-13
  cirrus_confid = qa.rightShift(14).bitwiseAnd(3).lt(2)  # bits 14-15
  
  temp = img.select(["ST_B10"],["surface_temp"]).multiply(0.00341802).add(149).add(-273.15)

  updated = (temp.updateMask(cloud1)
    .updateMask(cloud2)
    .updateMask(cloud3)
    .updateMask(cloudshadow)
    .updateMask(snow)
    .updateMask(cloud_confid)
    .updateMask(cloudsh_confid)
    .updateMask(snow_confid)
    .updateMask(cirrus_confid))

  return ee.Image(updated).copyProperties(img).set("system:time_start",systime).set("SOLAR_ZENITH_ANGLE", sza)


print("variables and functions imported")
# Out:
# variables and functions imported

# %% [markdown]
# ## **1.3 Define the lake area**
#
# In this section, use either *Option A*, where you define the bounding box, or *Option B* where you import a shape file of your lake.

# %% [markdown]
# ###Option A: use a bounding box
# Use the Rectangle tool on the map to draw a bounding box. The bounding box should be as small as possible while still including the entire lake surface. It cannot be a centroid location.<p>Do not run this block if you are using Option B.

# %%
#@markdown Run this block to generate a map and use the Rectangle tool to draw a bounding box. 
#@markdown The bounding box should be as small as possible while still including the entire lake surface. It cannot be a centroid location.
#@markdown If more than one box is drawn, the most recently drawn box will be used.
#@markdown <p>Do not run this block if you are using Option B.

from ipyleaflet import SearchControl, Marker, AwesomeIcon

'''pure leaflet'''
# baseMap = basemap_to_tiles(basemaps.CartoDB.DarkMatter)
m = Map(center=(15,0), zoom=2, scroll_wheel_zoom=True, layout=Layout(width='80%', height='500px'))

draw_control = DrawControl(rectangle={"shapeOptions":{"fillColor":"#3fca45d", "color":"#efed69", "fillOpacity": 0.25}}, circle={}, circlemarker={}, polygon={}, polyline={})
search_control = SearchControl(position="topright", url='https://nominatim.openstreetmap.org/search?format=json&q={s}', zoom=7)

gj = []
def handle_draw(self, action, geo_json):
  if action in ['created','edited']:
    gj.append(geo_json)
    box = ee.Geometry.Polygon(gj[-1]["geometry"]["coordinates"],None, False, 100)
    rec_geojson = gj[-1]["geometry"]["coordinates"]
    lon1, lat1 = rec_geojson[0][0]
    lon2, lat2 = rec_geojson[0][2]

draw_control.on_draw(handle_draw)
m.add_control(draw_control)
m.add_control(search_control)
m
# Out:
# Map(center=[15, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
#@markdown Run this block to set up your bounding box coordinates.
use_user_input_file = "no"
try:
  box = ee.Geometry.Polygon(gj[-1]["geometry"]["coordinates"],None, False, 100)
  rec_geojson = gj[-1]["geometry"]["coordinates"]
  lon1, lat1 = rec_geojson[0][0]
  lon2, lat2 = rec_geojson[0][2]

  center_lat = (lat1+lat2)/2
  center_lon = (lon1+lon2)/2

  print(f'''
  north bounds: {lat1}
  south bounds: {lat2}
  west bounds: {lon1}
  east bounds: {lon2}
  ''')
except IndexError:
  print("An error occurred, usually because this block was run but no box was drawn on the above map")
# Out:
#   north bounds: 43.317185
#   south bounds: 43.434972
#   west bounds: -72.089878
#   east bounds: -72.018122

# %% [markdown]
# ###Option B: upload a table file
# Using your Google Earth Engine account, upload a shapefile or csv of your study lake to your Assets and link to it here.<p>Click [here](https://drive.google.com/file/d/1lfFoZzQD_wAA7Bnil7mI4zwjKDG5kegh/view?usp=sharing) and [here](https://drive.google.com/file/d/1KNaZV63J_LUp6X1OcoLX1wonF0ASiIzi/view?usp=sharing) for screenshots of the process.

# %%
#@markdown Copy the asset path from Google Earth Engine and change
#@markdown dropdown to `yes`.
#@markdown File path should begin with 'users/'
user_input_file = "" #@param {type: "string"}
use_user_input_file = "no" #@param ["yes","no"] {allow-input: false}
#@markdown Remember to __run this block__ after filling in the above fields.
#@markdown Do not run this block if you are using Option A.

if use_user_input_file=="no":
  print("If you intend to use Option B, change the 'use_user_input_file' variable to 'yes' and rerun")
elif len(user_input_file)>1:
  shp = ee.FeatureCollection(user_input_file).geometry()
  centroid = shp.centroid(10).getInfo()["coordinates"]
  center_lat = centroid[1]
  center_lon = centroid[0]
  print(center_lat)
  print(center_lon)
else:
  print("No file input; will use Opt A bounding box coordinates")
  use_user_input_file = "no"

if 'shp' in globals() or 'shp' in locals():
  shp_map = folium.Map(location=[center_lat,center_lon],zoom_start=10,width=600,height=600)
  shp_map.add_child(folium.LatLngPopup())
  basemaps['Google Maps'].add_to(shp_map)
  shp_map.add_ee_layer(shp,{},'aoi')
  display(shp_map)
# else:
#   print("Display does not apply here; Opt A bounding box is being used for AOI")

# %% [markdown]
# ## **1.4 Set remaining user variables**
#
# This section defines acceptable water persistence and error for the Landsat pixels, the time period of interest, and confirms the path and row for Landsat acquisition. You can also change the default Google Drive folder for any outputs.

# %%
#@markdown We suggest saving the lakeCoSTR data to it's own folder in your Google Drive. 
#@markdown Replace your lake name where the following prompts read 'LAKENAME'. These folders
#@markdown will be automatically created within this script.

lake_name = 'sunapee_v1_12' #@param {type:"string"}
output_dir = "/content/drive/MyDrive/lakeCoSTR_output/"+ lake_name

#this parses the 'output_dir' string to get last listed subfolder
short_dir = lake_name
file_prefix = lake_name
print(f"Your data will be saved in {output_dir}")

if not os.path.exists(output_dir):
  os.makedirs(output_dir)

def check_splcharacter(test):
  string_check = re.compile('[@!#$%^&*() <>?/\|}{~:]')
  if not string_check.search(test)==None:
    print("Your file prefix contains special characters, please fix")
    lake_name = "LAKENAME"
  else:
    print("Files will all have the prefix:",test)

check_splcharacter(file_prefix)
# Out:
# Your data will be saved in /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12
# Files will all have the prefix: sunapee_v1_12

# %%
#@markdown Boundaries of water bodies are automatically detected using the JRC 
#@markdown Global Surface Water Mapping Layer dataset of percent water occurrence. 
#@markdown By default, a pixel has to be classified as water at least 55% of the 
#@markdown time. This is defined as `pctTime`. If your lake of interest experiences 
#@markdown significant fluctuations of lake level, we suggest using a higher percentage than the default. 

#@markdown <p>More information on this dataset can be found at https://doi.org/10.1038/nature20584



pctTime = 55  #@param {type: "number"}
#@markdown __Run this block__ after inputting the above parameter

water_fig = folium.Figure(width="60%")
water_map = folium.Map(location=[center_lat,center_lon],zoom_start=10,tiles=None).add_to(water_fig)
water_map.add_child(folium.LatLngPopup())

# blues = ["f7fbff","deebf7","c6dbef","9ecae1","6baed6","4292c6","2171b5","08519c","08306b"]
blues = ["FFFFFF","08306b"]

# basemaps['Google Satellite'].add_to(water_map)
folium.TileLayer('cartodbdark_matter').add_to(water_map)
water_map.add_ee_layer(box,{},'aoi')
water_map.add_ee_layer(openwater,{"min":pctTime, "max":100, "palette":blues}, 'water presence')
# water_map.add_ee_layer(box,{},'aoi')
print("Occurrence of water detected by Landsat where water is present at least ",pctTime,"% of the time (in blue)")
print("Water occurrence less than ", pctTime, "% of the time are in white")
display(water_fig)
# Out:
# Occurrence of water detected by Landsat where water is present at least  55 % of the time (in blue)
# Water occurrence less than  55 % of the time are in white
# <div style="width:60%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47186da7d7f5e86426307b77c7642526 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47186da7d7f5e86426307b77c7642526&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_47186da7d7f5e86426307b77c7642526 = L.map(
#                 &quot;map_47186da7d7f5e86426307b77c7642526&quot;,
#                 {
#                     center: [43.376078500000006, -72.054],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#                 var lat_lng_popup_c15c125276c00e5cf32e17d7a4bede41 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_c15c125276c00e5cf32e17d7a4bede41
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_47186da7d7f5e86426307b77c7642526);
#                     }
#                 map_47186da7d7f5e86426307b77c7642526.on(&#x27;click&#x27;, latLngPop);
#
#
#             var tile_layer_c1114f9be646a4031ca23e5a27af77de = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47186da7d7f5e86426307b77c7642526);
#
#
#
#         function geo_json_c381755114f5958f9627815bb954e8d1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c381755114f5958f9627815bb954e8d1 = L.geoJson(null, {
#                 onEachFeature: geo_json_c381755114f5958f9627815bb954e8d1_onEachFeature,
#
#         });
#
#         function geo_json_c381755114f5958f9627815bb954e8d1_add (data) {
#             geo_json_c381755114f5958f9627815bb954e8d1
#                 .addData(data)
#                 .addTo(map_47186da7d7f5e86426307b77c7642526);
#         }
#             geo_json_c381755114f5958f9627815bb954e8d1_add({&quot;coordinates&quot;: [[[-72.089878, 43.317185], [-72.089878, 43.434972], [-72.018122, 43.434972], [-72.018122, 43.317185], [-72.089878, 43.317185]]], &quot;geodesic&quot;: false, &quot;type&quot;: &quot;Polygon&quot;});
#
#
#
#             var tile_layer_ab6a6b9d4bb37e35c30fb19bd67feb8b = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/ed74ecc8bcfe278e492e3f8998b8091b-56f7dc508a902538da76487ae07ba4f7/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47186da7d7f5e86426307b77c7642526);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#@markdown Landsat scenes from both Tier 1 and Tier 2 of Collection 2 are 
#@markdown included for possible use. For Tier 2, specify the maximum spatial 
#@markdown error (in meters) for pixels. Only orthorectified images (L1T) are 
#@markdown considered. The default value is 24 meters.
rmse = 24  #@param {type: "number"}
#@markdown __Run this block__ after inputting the above parameter
print(f"Tier 2 L1T scenes with a maximum root mean square error of {rmse} meters will be considered")
# Out:
# Tier 2 L1T scenes with a maximum root mean square error of 24 meters will be considered

# %%
#@markdown Landsat thermal band records begin in 1982 with Landsat 4 Thematic Mapper (TM). 
#@markdown Enter the year range that you want to search, as well as months of 
#@markdown the year. To search all months, `m1 = 1` and `m2 = 12` <p>
#@markdown <p>First year (y1) and last year (y2). Years are inclusive, minimum value is 1982. <p>
#@markdown <p>First month (m1) and last month (m2). Months are inclusive.<p>
#@markdown <p>Note that this method has only been tested for temperature estimation where there is no ice present on the lake. 

y1 = 1982 #@param {type: "number"}
y2 =  2020#@param {type: "number"}

m1 =  5#@param {type: "number"}
m2 = 11 #@param {type: "number"}
print('Script will search years %d through %d and months %d through %d of each year' % (y1,y2,m1,m2))
#@markdown __Run this block__ after inputting the above parameters
# Out:
# Script will search years 1982 through 2020 and months 5 through 11 of each year

# %% [markdown]
# # **2. Find water pixels & delineate boundary**
# This step uses the bounding box or the table file as well as the water persistence using [JRC Water dataset](https://global-surface-water.appspot.com/) to define the waterbody area.
#
# Note, in some cases the _Opt A_ bounding box method will include upstream and downstream water areas, particularily where there are rivers that are large enough to be detected by Landsat. To avoid this, use the _Opt B_ table file method. <p>
# You can explore the JRC Water dataset [here](https://global-surface-water.appspot.com/).<p>

# %%
#@markdown This code block reduces the bounding box defined above to the largest water body present, and then counts the 30m pixels within the water body.<p>
#@markdown Landsat scenes included in analysis must have a minimum percentage of clear lake pixels available (these are discontinuous pixels). Default is 25%.
pctLakeCoverage = 25 #@param {type: "number"}
#@markdown __Run this block__ after inputting the above parameter

if use_user_input_file=="yes":
  try:
    box = shp
  except NameError:
    raise NameError('''Cannot find user-input file. Are you using Option B or 
    Opt A bounding box? You may need to correct and rerun.''')

wateroccurrence = sw.select(0)
water = wateroccurrence.gte(pctTime)
water = water.updateMask(water.neq(0))
 

#########################
# Find the biggest waterbody in the bounding box
def addArea(feature):
  # returns area +/- 1sqm
  return feature.set({'area':feature.geometry().area(1)})  

regions = water.addBands(wateroccurrence).reduceToVectors(
    reducer=ee.Reducer.min(),
    geometry=box,
    scale=30,
    maxPixels=5e9,
    geometryInNativeProjection=False,
    labelProperty='surfaceWater').map(addArea).sort('area',False);

lake_outline = ee.Feature(regions.first())
geo = lake_outline.geometry()

try:
  #########################
  # Find the best utm zone over the lake to generate CRS

  utm = utmbounds.filterBounds(box)
  utmJoin = ee.Join.saveBest('matches','best');
  utmCondition = ee.Filter.intersects(**{
      "rightField": '.geo',
      "leftField": '.geo'
  })
  utmJoined = utmJoin.apply(lake_outline, utm, utmCondition)
  
  try:
    getZone = utmJoined.getInfo()["features"][0]["properties"]["matches"]["properties"]["ZONE"]
    getHemi = utmJoined.getInfo()["features"][0]["properties"]["matches"]["properties"]["HEMISPHERE"]

    #indicate hemisphere  
    if getHemi == 'n':
      crs_out = f"EPSG:326{getZone}"
    else:
      crs_out = f"EPSG:327{getZone}"
    print("Data will be calculated with output CRS:",crs_out)
    #########################
    # print the user some pixel count statistics

    watercount = water.setDefaultProjection(crs_out).reduceRegion(reducer=ee.Reducer.count().unweighted(), 
                                    geometry=lake_outline.geometry(),
                                    scale=30, bestEffort=True)
    lakesurface = watercount.getInfo()["occurrence"]  # total pixels over lake

    pixel_min = round(lakesurface*(pctLakeCoverage/100.0))
    print("\nTotal # of lake pixels: ", lakesurface);
    print(f"{pctLakeCoverage}% of available lake pixels is", pixel_min)

    if lakesurface < 42:
      print('''Because lakeCoSTR only supplies aggregated data, 
      the lake you have selected has too few pixels available for 
      meaningful data aggregation. 
      It is not recommended that you use lakeCoSTR for this lake.''')
    else:
      #########################
      # Find the overlapping landsat path/rows

      pathrow = wrs2.filterBounds(geo)
        
      num_of_pr = len(pathrow.getInfo()["features"])
      path_west = 1
      path_east = 233
      row_north = 122
      row_south = 1

      for i in range(0,num_of_pr):
        pr = pathrow.getInfo()["features"][i]["properties"]["PR"]
        p = pr[:3]
        r = pr[3:]
        if int(p) > path_west:
          path_west = int(p)
        if int(p) < path_east:
          path_east = int(p)
        if int(r) < row_north:
          row_north = int(r)
        if int(r) > row_south:
          row_south = int(r)

      p1 = path_west
      p2 =  path_east
      r1 =  row_north
      r2 =  row_south
      print(f"\nYour lake overlaps {num_of_pr} landsat footprint(s)")
      print(f'bounding path(s): {path_west} (west) to {path_east} (east)')
      print(f'bounding row(s): {row_north} (north) to {row_south} (south)\n')


      ##### Attempt to find the "best" path/row by comparing footprints that completely
      ## contain the lake, or if none completely contain, find the footprint that has
      ## the most overlap

      footprintJoinAll = ee.Join.saveAll('matches')
      footprintJoinBest = ee.Join.saveBest(**{'matchKey':'matches','measureKey':'best'})

      footprintContains = ee.Filter.isContained(**{'rightField':'.geo','leftField':'.geo'})
      footprintIntersects = ee.Filter.intersects(**{'rightField':'.geo','leftField':'.geo'})

      allContained = footprintJoinAll.apply(lake_outline,pathrow,footprintContains)
      anyIntersects = footprintJoinBest.apply(lake_outline,pathrow,footprintIntersects)

      try:
        containedMatches = allContained.getInfo()["features"][0]["properties"]["matches"]
      except IndexError:
        containedMatches = []

      intersectedMatches = anyIntersects.getInfo()["features"][0]["properties"]["matches"]

      #########################
      # Display a map

      pixel_fig = folium.Figure(width="50%")
      pixel_map = folium.Map(location=[center_lat,center_lon],zoom_start=6).add_to(pixel_fig)
      basemaps['Google Maps'].add_to(pixel_map)
      pixel_map.add_ee_layer(pathrow,{},'path row')

      def addFPtoMap(list_of_fps):
        for fp in list_of_fps:
          makeGeojson = folium.GeoJson(fp["geometry"])
          fpPath = str(fp["properties"]["PATH"])
          fpRow = str(fp["properties"]["ROW"])
          popup = folium.Popup("P"+fpPath+" R"+fpRow)
          popup.add_to(makeGeojson)
          makeGeojson.add_to(pixel_map)

      if len(containedMatches)>0: #lake is fully contained by at least 1 path-row
        if num_of_pr == 1: 
          addFPtoMap(containedMatches)
          print('''Great news! Your lake is completely contained by a single path-row footprint.
          Because your lake does not cross multiple WRS2 rows, there's nothing more you need to do.
          You can skip the next codeblock and move to the 'Get Skin Surface Temperatures' section.
          ''')
        elif len(intersectedMatches) == 0: #and the lake doesn't have any partial matches
          addFPtoMap(containedMatches)
          if(row_north-row_south) == 0: #if it is contained by only one row
            print('''Great news! Your lake is completely contained by at least one path-row footprint.
            Because your lake does not cross multiple WRS2 rows, there's nothing more you need to do.
            You can skip the next codeblock and move to the 'Get Skin Surface Temperatures' section.
            ''')
          else: #if it is contained by multiple rows
            print('''Great news! Your lake is completely contained by multiple WRS2 path-row footprints, 
            HOWEVER, those footprints include multiple WRS2 rows in the same WRS2 path. In order to not retreive near-duplicate 
            temperature estimates from neghboring WRS2 rows, please *manually input* a single ROW value for `new_row_north` and 
            `new_row_south` in the codeblock below. We reccommend you choose the row that is closest to the equator (a lower row number in the Northern 
            Hemisphere, or a higher row number in the Southern Hemisphere).
            ''')
            print("Click the blue highlighted footprint to see the path and row")
        elif len(intersectedMatches)>0: #if it has partial matches
          if len(containedMatches) >0: #and it has fully contained matches
            addFPtoMap(containedMatches)
            print('''Great news! Your lake is completely contained by at least one path-row footprint, 
            HOWEVER, you need to *manually input* the path and row values for the blue box(es) displayed 
            in the map below into the next code block because the overlapping path-row combinations 
            outlined in black do/does not completely contain your lake.
            ''')
            print("Click the blue highlighted footprint to see the path and row")
      else: #otherwise, you're outta luck
        print('''
        CAUTION: Your lake is not completely contained by a single WRS2 path-row footprint. lakeCoSTR functions best
        when your lake is completely contained by at least one WRS2 path-row footprint. Because of this, we do not 
        recommend the use of lakeCoSTR to acquire surface temperature estimates for your lake. 
        ''')

      pixel_map.add_ee_layer(lake_outline.geometry(), {}, 'lake area')
      display(pixel_map)
  except:
    print('''An error occurred - either you have different selections of lake area and 
    water occurrance area (double check sections 1.3 and 1.4) or the lake you selected is 
    too large to process in lakeCoSTR.''')
except IndexError:
  print('''An error occurred - this could be because there are no water pixels available for analysis.
  Check the map in above step to see if there are water pixels available for analysis.''')
# Out:
# Data will be calculated with output CRS: EPSG:32618
#
# Total # of lake pixels:  17165
# 25% of available lake pixels is 4291
#
# Your lake overlaps 1 landsat footprint(s)
# bounding path(s): 13 (west) to 13 (east)
# bounding row(s): 30 (north) to 30 (south)
#
# Great news! Your lake is completely contained by a single path-row footprint.
#           Because your lake does not cross multiple WRS2 rows, there's nothing more you need to do.
#           You can skip the next codeblock and move to the 'Get Skin Surface Temperatures' section.
# <div style="width:50%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c731e875a7d3d736593f2be30449667 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c731e875a7d3d736593f2be30449667&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3c731e875a7d3d736593f2be30449667 = L.map(
#                 &quot;map_3c731e875a7d3d736593f2be30449667&quot;,
#                 {
#                     center: [43.376078500000006, -72.054],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_257200fd1e681b0e6c5a49e035d11dcb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c731e875a7d3d736593f2be30449667);
#
#
#             var tile_layer_df695969b8a56d93a11d380469fc3962 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c731e875a7d3d736593f2be30449667);
#
#
#             var tile_layer_d516e718620c23ac61d9aef5b53eb214 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/77cca7d8567bf2e82b85b68e3c112a6c-6d1916cfa11b02c4ae2dfac3908bb346/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3c731e875a7d3d736593f2be30449667);
#
#
#
#         function geo_json_f587bd3766dabaf48d16ddfaea1bbca6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f587bd3766dabaf48d16ddfaea1bbca6 = L.geoJson(null, {
#                 onEachFeature: geo_json_f587bd3766dabaf48d16ddfaea1bbca6_onEachFeature,
#
#         });
#
#         function geo_json_f587bd3766dabaf48d16ddfaea1bbca6_add (data) {
#             geo_json_f587bd3766dabaf48d16ddfaea1bbca6
#                 .addData(data)
#                 .addTo(map_3c731e875a7d3d736593f2be30449667);
#         }
#             geo_json_f587bd3766dabaf48d16ddfaea1bbca6_add({&quot;coordinates&quot;: [[[-73.77839982357561, 42.5959016942376], [-73.77803868706364, 42.59584817909746], [-73.74362557373134, 42.59083649834542], [-73.70921240692674, 42.58582485630977], [-73.67479931680182, 42.58081312247142], [-73.6403861640629, 42.57580149130678], [-73.60597307880899, 42.57078975948157], [-73.57156001146204, 42.56577813450944], [-73.53714682249156, 42.56076644633946], [-73.5027337317845, 42.55575472344867], [-73.46832059971405, 42.5507430871064], [-73.43390755627088, 42.54573140696146], [-73.39949437175648, 42.540719717925256], [-73.36508126601338, 42.53570804865759], [-73.33066818909829, 42.53069631500564], [-73.29625509099235, 42.52568465123713], [-73.26184192160197, 42.52067297300956], [-73.22742881076499, 42.51566129574976], [-73.19301570832359, 42.510649607953184], [-73.15860265407662, 42.5056379115957], [-73.12418950771689, 42.500626254301395], [-73.08977639898269, 42.495614578724485], [-73.05536327750684, 42.49060287317013], [-73.02095018293467, 42.48559121237401], [-72.98653706479625, 42.4805795117176], [-72.95212396266145, 42.47556784590056], [-72.91771082595892, 42.47055613021164], [-72.88329769418405, 42.465544512133484], [-72.84888460681465, 42.4605327750781], [-72.81447151314887, 42.455521125515666], [-72.78005836241633, 42.450509405729875], [-72.74564528415311, 42.445497777073676], [-72.71123213732938, 42.44048606785344], [-72.67681905143405, 42.43547436663479], [-72.64240597553993, 42.430462734044085], [-72.60799285865352, 42.425451012187196], [-72.57357973996395, 42.420439348412515], [-72.53916656838321, 42.41542765753865], [-72.50475347330261, 42.41041595543491], [-72.47034040357623, 42.40540430252384], [-72.43592721769882, 42.40039259929906], [-72.40151413528267, 42.39538094868363], [-72.3671010147425, 42.390369251108865], [-72.33268789504379, 42.38535758102732], [-72.29827481513536, 42.380345940123846], [-72.26386172359722, 42.37533424293655], [-72.22944856894831, 42.37032254948743], [-72.19503548039475, 42.365310875812774], [-72.16062240640038, 42.36029920913902], [-72.12620920497369, 42.35528752208315], [-72.09179609564546, 42.350275845220445], [-72.05738302676541, 42.34526416567742], [-72.02296994662439, 42.3402524704846], [-71.98855680345525, 42.33524074657644], [-71.95414372632871, 42.330229082901475], [-71.91973057296704, 42.325217378914374], [-71.88531747239867, 42.320205723586376], [-71.85090437272072, 42.31519403097943], [-71.81649

# %%
#@markdown If ther previous code block directed you to `*manually input*` WRS2 path-row values, 
#@markdown please enter the values for path ('P') and row ('R') as indicated by clicking on the
#@markdown blue box in the map above. 

#@markdown <br>If you weren't directed to change your the WRS2 path-row parameters, leave these blank.

new_path_west = "" #@param {type:'string'}
new_path_east = "" #@param {type: 'string'}
new_row_north = "" #@param {type: 'string'}
new_row_south = "" #@param {type: 'string'}

if new_path_west:
  p1 = int(new_path_west)
else: 
  p1 =  path_west
if new_path_east:
  p2 =  int(new_path_east)
else:
  p2 = path_east
if new_row_north:
  r1 =  int(new_row_north)
else:
  r1 = row_north
if new_row_south:
  r2 =  int(new_row_south)
else:
  r2 = row_south

print(f'new bounding path(s): {p1} (west) to {p2} (east)')
print(f'new bounding row(s): {r1} (north) to {r2} (south)\n')

# %% [markdown]
# # **3. Get Skin Surface Temperatures**

# %%
#@markdown **Run this block** to filter by date and site location, convert 
#@markdown temperature from K --> C, compile and stack images, and carry over the metadata. 

#For landsat 8, any scenes with possible image quality 
#issues due to Scene Select Mirror (SSM) position are removed.

l4 = (l4t1.merge(l4t2).filterMetadata('L1_PROCESSING_LEVEL','equals','L1TP') \
      .filterMetadata('GEOMETRIC_RMSE_MODEL','not_greater_than',rmse) \
      .filterBounds(geo) \
      .filter(ee.Filter.calendarRange(y1,y2,'year')) \
      .filter(ee.Filter.calendarRange(m1,m2,'month')) \
      .filterMetadata('WRS_ROW','not_less_than',r1).filterMetadata('WRS_ROW','not_greater_than',r2) \
      .filterMetadata('WRS_PATH','not_greater_than',p1).filterMetadata('WRS_PATH','not_less_than',p2) \
      .map(prep457bands, True))

l5 = (l5t1.merge(l5t2).filterMetadata('L1_PROCESSING_LEVEL','equals','L1TP') \
      .filterMetadata('GEOMETRIC_RMSE_MODEL','not_greater_than',rmse) \
      .filterBounds(geo) \
      .filter(ee.Filter.calendarRange(y1,y2,'year')) \
      .filter(ee.Filter.calendarRange(m1,m2,'month')) \
      .filterMetadata('WRS_ROW','not_less_than',r1).filterMetadata('WRS_ROW','not_greater_than',r2) \
      .filterMetadata('WRS_PATH','not_greater_than',p1).filterMetadata('WRS_PATH','not_less_than',p2) \
      .map(prep457bands, True))

l7 = (l7t1.merge(l7t2).filterMetadata('L1_PROCESSING_LEVEL','equals','L1TP') \
      .filterMetadata('GEOMETRIC_RMSE_MODEL','not_greater_than',rmse) \
      .filterBounds(geo) \
      .filter(ee.Filter.calendarRange(y1,y2,'year')) \
      .filter(ee.Filter.calendarRange(m1,m2,'month')) \
      .filterMetadata('WRS_ROW','not_less_than',r1).filterMetadata('WRS_ROW','not_greater_than',r2) \
      .filterMetadata('WRS_PATH','not_greater_than',p1).filterMetadata('WRS_PATH','not_less_than',p2) \
      .map(prep457bands, True))

l8 = (l8t1.merge(l8t2).filterMetadata('L1_PROCESSING_LEVEL','equals','L1TP') \
      .filterMetadata('GEOMETRIC_RMSE_MODEL','not_greater_than',rmse) \
      .filterBounds(geo) \
      .filter(ee.Filter.calendarRange(y1,y2,'year')) \
      .filter(ee.Filter.calendarRange(m1,m2,'month')) \
      .filterMetadata('WRS_ROW','not_less_than',r1).filterMetadata('WRS_ROW','not_greater_than',r2) \
      .filterMetadata('WRS_PATH','not_greater_than',p1).filterMetadata('WRS_PATH','not_less_than',p2) \
      .filterMetadata('TIRS_SSM_POSITION_STATUS','not_equals','SWITCHED') \
      .map(prep8bands, True))

landsat = ee.ImageCollection(l4).merge(l5).merge(l7).merge(l8)

print("Landsat compiled at", strftime("%x %X"))

'''
Add metadata to each scene that indicates how many visible pixels were included 
in analysis, and filter images so that only scenes with the minimum number of 
pixels remain.
'''
def countPixels(img):
  img = ee.Image(img)
  getCount = img.reduceRegion(**{
      "reducer": ee.Reducer.count(),
      "geometry": geo, 
      "scale": 30})
  count = ee.Dictionary(getCount).get('surface_temp')
  return img.set('pixel_count',count)
before = landsat.map(countPixels)
countedPixels = before.filterMetadata('pixel_count','not_less_than', pixel_min)
print('Total number of LS scenes:',len(before.getInfo()['features']),'\nNumber of LS scenes after filter:', len(countedPixels.getInfo()['features']))
print("Landsat filtered:", strftime("%x %X"))
# Out:
# Landsat compiled at 09/06/22 21:08:46
# Total number of LS scenes: 603
# Number of LS scenes after filter: 319
# Landsat filtered: 09/06/22 21:09:23

# %% [markdown]
# # **4. Data Visualization**
# The code blocks in the following section allow you to explore your results using dataframes and pixel-value distributions. You can visually inspect each scene for errant data or export the data to explore further.

# %%
#@title 4.1 Convert data from server-side EE objects to client-side Python objects
#@markdown __Run this block__ to define functions for data exploration


# These functions convert image pixels to numpy arrays
def createArrays(img):
  psi_prop = ee.Image(img).sampleRectangle(region=geo, defaultValue=-1)
  getProp = psi_prop.get("surface_temp")
  return img.set("img_array", getProp)

def getArrays(client_img_col):
  list_of_arrays = []
  for img in client_img_col:
    prop = img["properties"]["img_array"]
    a = np.array(prop)
    list_of_arrays.append(a)
  return list_of_arrays
print('Conversion function imported.')

def generate_histogram(img):
  img = ee.Image(img)
  fhisto = img.reduceRegion(**{
      "reducer": ee.Reducer.fixedHistogram(-5,30,70).unweighted(),
      "geometry": geo,
      "scale": 30,
      "maxPixels": 5e9
  })
  return img.set('histogram',fhisto.get('surface_temp'))
print("Will generate histograms with a fixed x-axis between -5 - 30 deg C in 0.5 degree bins")
# Out:
# Conversion function imported.
# Will generate histograms with a fixed x-axis between -5 - 30 deg C in 0.5 degree bins

# %%
# @markdown This code block executes the functions from the previous block and 
# @markdown converts the image collection from a server-side EE object to a client-side 
# @markdown Python object. This allows iteration over the image collection with a `for` 
# @markdown loop, which provides much more Python functionality.<p><mark>__This step 
# @markdown could take some time to run</mark> depending on the length of the 
# @markdown ImageCollection.__

# @markdown If you recieve an error at this step that `your response size exceeds limit`, 
# @markdown you will need to go back and reduce the number of years of data you are requesting. 

print("Start:", strftime("%x %X"))
imgs_histo = countedPixels.map(generate_histogram)
generate_arrays = imgs_histo.map(createArrays)

imgCol = generate_arrays.getInfo()["features"]
print("Finish:", strftime("%x %X"))
print("Number of Landsat scenes: ", len(imgCol))
# Out:
# Start: 09/06/22 21:10:25
# Finish: 09/06/22 21:11:43
# Number of Landsat scenes:  319

# %%
#@markdown Now that the image collection is client-side, __run this block__ to 
#@markdown get arrays of each image.
# returns a list of arrays
imgs_to_arrays = getArrays(imgCol)
print("Converted images to arrays")
# Out:
# Converted images to arrays

# %%
#@title 4.2 Collated pixel distributions
#@markdown __Run this block__ to iterate through the image collection and convert 
#@markdown all bins and frequencies to a single Pandas `DataFrame`. 

length_plots = len(imgCol)
list_of_dfs = []
list_of_uids = []

# fig = make_subplots(rows=length_plots, cols=1)
for i in imgCol:
  uid = (i['properties']['L1_LANDSAT_PRODUCT_ID'])
  list_of_uids.append(uid)
  histogram = i["properties"].get("histogram")

  a = pd.DataFrame(histogram, columns=["bin",uid]).set_index("bin")
  # fig.add_histogram()
  list_of_dfs.append(a)

appended_dfs = pd.concat(list_of_dfs,ignore_index=False, axis=1)
transposed_dfs = appended_dfs.T

# %%
#@title 4.3 View pixel distribution using `matplotlib`
#@markdown __Run this block__ to generate histograms for each lake temperature 
#@markdown Landsat scene. Each scene is saved as png in a folder 'histograms' in the lakeCoSTR_output directory. 
#@markdown This step can take some time to run.

#print(len(list_of_uids)," histograms will be generated")
print("Start:", strftime("%x %X"))

#make 'histogram' folder in defined directory
if not os.path.exists(os.path.join(output_dir, 'histograms')):
    os.makedirs(os.path.join(output_dir, 'histograms'))

histo_dir = os.path.join(output_dir, 'histograms')

print("Histograms will be saved at ", histo_dir)

histos = appended_dfs
#list of scenes
scenes = histos.columns
histos = pd.DataFrame.transpose(histos) #reorient data
#reset index
histos = histos.reset_index()
histos_vert = histos.melt(id_vars=['index'])

#iterate over the scene list
for i in range(0, len(scenes)):
  df = histos_vert[histos_vert['index'] == scenes[i]]
  histoname = os.path.join(histo_dir,scenes[i]+'_histo.png')
  plt.bar(x = df.bin, height = df.value)
  plt.ylabel('frequency')
  plt.xlabel('temperature (deg C)')
  plt.title(scenes[i])
  plt.savefig(histoname)
  print('Saving histogram for Landsat scene ', scenes[i], ' at ', histoname)  
  plt.close()

print("Finish:", strftime("%x %X"), 'Your histograms should now be visible at ', histo_dir)
# Out:
# Start: 09/06/22 21:11:53
# Histograms will be saved at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms
# Saving histogram for Landsat scene  LT04_L1TP_013030_19870526_20201014_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT04_L1TP_013030_19870526_20201014_02_T1_histo.png
# Saving histogram for Landsat scene  LT04_L1TP_013030_19890819_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT04_L1TP_013030_19890819_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT04_L1TP_013030_19900721_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT04_L1TP_013030_19900721_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19840610_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19840610_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19840930_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19840930_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19841016_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19841016_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19850901_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19850901_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19850917_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19850917_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19851120_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19851120_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19860515_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19860515_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19860718_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19860718_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19861022_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19861022_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19870502_20201014_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19870502_20201014_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19870619_20201014_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19870619_20201014_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19870806_20201014_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19870806_20201014_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19871009_20201014_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19871009_20201014_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19871025_20201014_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19871025_20201014_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19880605_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19880605_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19880621_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19880621_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19880707_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19880707_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19880723_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19880723_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19880909_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19880909_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19880925_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19880925_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19881027_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19881027_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19881112_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19881112_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19890507_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19890507_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19890726_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19890726_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19890827_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19890827_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19890928_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19890928_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19891014_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19891014_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19891030_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19891030_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19900526_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19900526_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19900627_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19900627_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19900729_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19900729_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19900830_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19900830_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19901001_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19901001_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19901017_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19901017_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910513_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910513_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910529_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910529_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910716_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910716_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910801_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910801_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910817_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910817_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910902_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910902_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19910918_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19910918_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19911004_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19911004_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19911105_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19911105_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19920515_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19920515_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19920616_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19920616_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19920819_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19920819_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19920920_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19920920_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19921006_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19921006_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19921022_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19921022_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19930502_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19930502_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19930705_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19930705_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19930806_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19930806_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19931025_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19931025_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19931110_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19931110_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19931126_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19931126_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19940521_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19940521_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19940622_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19940622_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19940724_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19940724_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19940809_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19940809_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19940825_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19940825_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19940910_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19940910_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19941012_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19941012_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19941028_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19941028_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19941113_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19941113_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19941129_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19941129_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19950508_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19950508_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19950727_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19950727_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19951116_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19951116_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19960526_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19960526_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19960814_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19960814_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19960830_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19960830_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19960915_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19960915_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19961001_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19961001_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19961017_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19961017_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19970614_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19970614_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19970630_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19970630_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19971105_20200909_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19971105_20200909_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19980516_20200909_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19980516_20200909_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19980703_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19980703_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19990604_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19990604_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19990722_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19990722_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19990807_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19990807_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19990823_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19990823_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19990924_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19990924_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19991026_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19991026_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_19991111_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_19991111_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20000708_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20000708_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20000825_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20000825_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20000910_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20000910_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20001012_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20001012_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010508_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010508_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010609_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010609_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010625_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010625_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010727_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010727_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010828_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010828_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010913_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010913_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20010929_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20010929_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20011116_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20011116_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20020511_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20020511_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20020714_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20020714_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20021018_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20021018_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20021103_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20021103_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20030615_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20030615_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20030701_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20030701_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20030717_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20030717_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20030818_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20030818_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20031122_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20031122_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20040703_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20040703_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20041007_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20041007_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20041108_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20041108_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050503_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050503_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050519_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050519_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050604_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050604_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050620_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050620_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050807_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050807_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050823_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050823_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050908_20200901_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050908_20200901_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20050924_20200901_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20050924_20200901_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20051111_20200901_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20051111_20200901_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20060725_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20060725_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20060911_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20060911_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20060927_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20060927_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20061013_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20061013_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070509_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070509_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070525_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070525_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070610_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070610_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070626_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070626_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070712_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070712_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070813_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070813_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070829_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070829_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20070914_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20070914_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20080511_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20080511_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20080612_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20080612_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20080831_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20080831_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20081018_20200828_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20081018_20200828_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20090530_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20090530_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20090818_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20090818_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20090919_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20090919_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20091021_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20091021_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20091122_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20091122_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20100517_20200824_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20100517_20200824_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20100602_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20100602_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20100618_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20100618_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20100704_20200824_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20100704_20200824_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20100906_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20100906_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20100922_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20100922_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20101008_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20101008_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20110621_20200822_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20110621_20200822_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20110707_20200822_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20110707_20200822_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20110824_20200820_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20110824_20200820_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20111011_20200820_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20111011_20200820_02_T1_histo.png
# Saving histogram for Landsat scene  LT05_L1TP_013030_20111112_20200820_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LT05_L1TP_013030_20111112_20200820_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_19990730_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_19990730_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_19990831_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_19990831_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_19991002_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_19991002_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20000918_20200918_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20000918_20200918_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20001020_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20001020_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20010601_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20010601_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20010905_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20010905_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20011108_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20011108_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20020604_20200917_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20020604_20200917_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20020620_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20020620_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20020706_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20020706_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20020722_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20020722_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20020908_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20020908_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20020924_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20020924_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20030725_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20030725_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20030826_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20030826_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20031013_20200916_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20031013_20200916_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20031114_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20031114_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20040711_20200915_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20040711_20200915_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20050511_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20050511_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20050714_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20050714_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20050730_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20050730_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20051002_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20051002_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20051103_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20051103_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20051119_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20051119_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20060530_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20060530_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20060701_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20060701_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20060717_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20060717_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20060802_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20060802_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20060919_20200914_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20060919_20200914_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20061005_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20061005_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20061021_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20061021_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20070501_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20070501_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20070602_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20070602_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20070618_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20070618_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20070805_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20070805_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20070906_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20070906_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20070922_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20070922_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20071125_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20071125_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20080706_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20080706_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20080807_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20080807_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20080823_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20080823_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20080908_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20080908_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20080924_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20080924_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20081010_20200913_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20081010_20200913_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20081026_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20081026_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20081127_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20081127_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20090522_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20090522_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20100525_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20100525_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20100728_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20100728_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20100829_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20100829_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20100914_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20100914_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20101117_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20101117_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20110512_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20110512_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20110629_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20110629_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20110715_20200909_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20110715_20200909_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20110731_20200909_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20110731_20200909_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20110901_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20110901_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20111104_20200909_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20111104_20200909_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20120615_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20120615_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20120802_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20120802_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20120818_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20120818_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20120903_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20120903_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20120919_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20120919_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20121005_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20121005_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20121106_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20121106_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20121122_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20121122_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130501_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130501_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130517_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130517_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130602_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130602_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130720_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130720_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130805_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130805_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130821_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130821_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20130906_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20130906_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20131008_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20131008_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20131109_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20131109_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20131125_20200907_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20131125_20200907_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20140520_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20140520_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20140707_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20140707_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20140723_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20140723_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20140808_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20140808_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20140824_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20140824_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20141027_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20141027_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20150507_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20150507_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20150523_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20150523_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20150624_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20150624_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20150710_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20150710_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20150912_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20150912_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20150928_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20150928_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20151030_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20151030_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20160525_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20160525_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20160626_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20160626_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20160712_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20160712_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20160829_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20160829_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20160914_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20160914_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20170715_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20170715_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20170731_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20170731_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20170901_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20170901_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20170917_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20170917_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20171003_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20171003_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20171019_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20171019_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20171104_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20171104_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20180531_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20180531_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20180702_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20180702_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20180718_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20180718_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20180819_20200829_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20180819_20200829_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20180904_20200828_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20180904_20200828_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20181022_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20181022_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20181107_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20181107_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20190518_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20190518_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20190603_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20190603_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20190705_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20190705_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20190806_20200824_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20190806_20200824_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20190822_20200824_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20190822_20200824_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20190907_20200824_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20190907_20200824_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20191009_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20191009_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20191126_20200823_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20191126_20200823_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20200520_20200820_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20200520_20200820_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20200621_20200822_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20200621_20200822_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20200824_20200920_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20200824_20200920_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20200909_20201005_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20200909_20201005_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20200925_20201021_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20200925_20201021_02_T1_histo.png
# Saving histogram for Landsat scene  LE07_L1TP_013030_20201011_20201107_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LE07_L1TP_013030_20201011_20201107_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20130930_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20130930_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20140512_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20140512_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20140629_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20140629_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20140901_20200911_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20140901_20200911_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20140917_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20140917_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20141003_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20141003_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20141120_20200910_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20141120_20200910_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20150702_20200909_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20150702_20200909_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20150803_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20150803_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20150819_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20150819_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20151123_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20151123_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20160618_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20160618_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20160704_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20160704_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20160720_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20160720_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20160805_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20160805_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20160922_20200906_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20160922_20200906_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20161024_20200905_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20161024_20200905_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20170504_20200904_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20170504_20200904_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20170520_20201015_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20170520_20201015_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20170621_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20170621_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20170723_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20170723_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20170824_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20170824_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20170925_20200903_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20170925_20200903_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20171027_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20171027_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20171112_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20171112_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20171128_20200902_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20171128_20200902_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20180523_20200901_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20180523_20200901_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20180710_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20180710_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20180827_20200831_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20180827_20200831_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20181014_20200830_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20181014_20200830_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190526_20200828_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190526_20200828_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190627_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190627_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190713_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190713_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190729_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190729_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190814_20200827_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190814_20200827_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190830_20200826_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190830_20200826_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20190915_20200826_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20190915_20200826_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20191102_20200825_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20191102_20200825_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20200715_20200912_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20200715_20200912_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20200731_20200908_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20200731_20200908_02_T1_histo.png
# Saving histogram for Landsat scene  LC08_L1TP_013030_20200917_20201005_02_T1  at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms/LC08_L1TP_013030_20200917_20201005_02_T1_histo.png
# Finish: 09/06/22 21:12:48 Your histograms should now be visible at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/histograms

# %% [markdown]
# # **5. Export Landsat temperature statistics to CSV**

# %%
#@markdown Execute this cell block to export a CSV containing temperature and related image metadata to your Google Drive.

def exportWholeLakeStats(img):
  img = ee.Image(img).clip(geo)

  # retrieve image metadata for output file
  landsattime = img.get('system:time_start')
  cloudcover_pct_scene = img.get('CLOUD_COVER')
  esd_au_scene = img.get("EARTH_SUN_DISTANCE")
  sunelev_deg_scene = img.get('SUN_ELEVATION')
  sunazi_deg_scene = img.get('SUN_AZIMUTH')
  solzenang_deg_scene = img.get('SOLAR_ZENITH_ANGLE')
  count = img.get('pixel_count')
  pctAvail = ee.Number(count).divide(lakesurface).multiply(100)

  # get statistics for skin_temperature
  reducers = ee.Reducer.mean().combine(**{
      "reducer2": ee.Reducer.stdDev(), "sharedInputs":True}).combine(**{
      "reducer2": ee.Reducer.minMax(), "sharedInputs":True}).combine(**{
      "reducer2": ee.Reducer.median(**{"maxBuckets":500, "minBucketWidth": 0.125}), "sharedInputs":True}).combine(**{
      "reducer2": ee.Reducer.skew(), "sharedInputs":True}).combine(**{
      "reducer2": ee.Reducer.kurtosis(), "sharedInputs":True}).combine(**{
      "reducer2": ee.Reducer.percentile(**{"percentiles": [25,75], "maxBuckets": 500, "minBucketWidth": 0.125}), "sharedInputs":True})
      
  
  stats = img.reduceRegion(**{
      "reducer": reducers,
      "geometry": geo,
      "scale": 30,
      "crs": crs_out,
      "maxPixels": 5e9
  })
  
  more_stats = ee.Dictionary({'availablePixels_count':count,
                            'datetime_landsat':landsattime,
                            'cloudcover_pct_scene':cloudcover_pct_scene,
                            'sunelev_deg_scene':sunelev_deg_scene,
                            'sunazi_deg_scene':sunazi_deg_scene,
                            'esd_au_scene':esd_au_scene,
                            'sunazi_deg_scene':sunazi_deg_scene,
                            'lakeCoverage_pct':pctAvail,
                            #'datetime_landsat_excelformat':ee.Number(landsattime).divide(1000.0).divide(86400).add(25569)
                            })
  stats2 = ee.Dictionary.combine(stats, more_stats)

  return ee.Feature(None,stats2)

temp_stats = countedPixels.map(exportWholeLakeStats)

#create the file name with user-specified prefix
temp_filename = (file_prefix+'_temp_stats')

export_task = ee.batch.Export.table.toDrive(**{
    'collection': temp_stats,
    'description': temp_filename,
    "fileFormat": "CSV",
    'folder': short_dir
})

print("Exporting ", temp_filename+".csv")
export_task.start()
print('Polling for task (id: {}) at'.format(export_task.id))

while export_task.active():
  print(strftime("%x %X"), export_task.status())
  sleep(10)

print("Finished:", strftime("%x %X"))

print('Export should now be visible in Drive at path:\n',os.path.join(output_dir, temp_filename + ".csv"))
# Out:
# Exporting  sunapee_v1_12_temp_stats.csv
# Polling for task (id: ZUXLNN7ROPFCI37RHPJ7VGJM) at
# 09/06/22 21:13:39 {'state': 'READY', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498819420, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:13:50 {'state': 'READY', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498819420, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:14:01 {'state': 'READY', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498819420, 'start_timestamp_ms': 0, 'task_type': 'EXPORT_FEATURES', 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:14:11 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:14:22 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:14:33 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:14:43 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:14:54 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:15:04 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:15:15 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:15:26 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:15:36 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:15:47 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:15:57 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:16:08 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:16:19 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:16:29 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498846098, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:16:39 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:16:50 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:17:01 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:17:11 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:17:22 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:17:33 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:17:43 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:17:53 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:18:04 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:18:14 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:18:25 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:18:35 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:18:46 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:18:56 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662498996068, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:19:07 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:19:18 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:19:28 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:19:39 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:19:49 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:20:00 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:20:11 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:20:21 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:20:32 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# 09/06/22 21:20:42 {'state': 'RUNNING', 'description': 'sunapee_v1_12_temp_stats', 'creation_timestamp_ms': 1662498819420, 'update_timestamp_ms': 1662499146067, 'start_timestamp_ms': 1662498846047, 'task_type': 'EXPORT_FEATURES', 'attempt': 1, 'id': 'ZUXLNN7ROPFCI37RHPJ7VGJM', 'name': 'projects/earthengine-legacy/operations/ZUXLNN7ROPFCI37RHPJ7VGJM'}
# Finished: 09/06/22 21:20:53
# Export should now be visible in Drive at path:
#  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/sunapee_v1_12_temp_stats.csv

# %% [markdown]
# # **6. Pair Landsat with *in situ* data**
# This next section is optional, but allows you to compare any field data you may have to the Landsat data produced here. This section uses the CSV exported above.<p>
# In order for this to run successfully, your data must be in CSV format and have the following headers/columns:
#
#
# *  `datetime`: Date and time of each temperature reading in a recognized strftime format
# *  `temp_degC`: an integer or float number representing temperature in degrees Celcius
# *  `location`: for in-lake statistics, a column with lake zone names (string format, no special characters); can be all the same for a single output or differentiated by lake zones/sensors
# * `depth_m`: as an integer or float number, for statistics about the depth of sensors for matched scenes
#
# The file may have additional columns, but the above are mandatory fields. To see an example dataset, click here.

# %% [markdown]
# ## 6.1 Upload CSV of *insitu* data
# Choose an option below. For more ways to import data, see [here](https://colab.research.google.com/notebooks/io.ipynb)

# %%
#@title Please provide some information about your data
#@markdown What timezone is your data? <a href="https://en.wikipedia.org/wiki/List_of_tz_database_time_zones" target="_blank">Olson Times Wikipedia Page</a> Specifically, you need to indicate the UTC offset for your data for proper pairing, including whether or not your data timestamp observes Daylight Savings Time. Enter the text for the matching UTC offset and DST behavior from the 'TZ database name' column in the linked table. Note that the sign of the GMT offset is intentionally inverted from the UTC offset.
insitu_timezone = "Etc/GMT+5" #@param {type:"string"}
#@markdown How is your datetime formatted? Please use <a href='https://strftime.org/' target='_blank'>strftime</a> format.
datetime_format = "%Y-%m-%d %H:%M:%S" #@param {type:"string"}

# %%
#@title Option 1: Link to raw CSV from Github
pasted_path = "" #@param {type:"string"}

is_df = pd.read_csv(pasted_path)
#is_df["datetime"] = pd.to_datetime(is_df["datetime"])
print("dataframe created")

# %%
#@title Option 2: Upload CSV from your Google Drive folder
#@markdown using the folder icon on the left hand side, navigate to the file in
#@markdown your Google Drive (named 'drive' here), click on the three vertical dots to the right of the file
#@markdown and click on 'copy file path'. Paste the copied path below.

pasted_path = "" #@param {type:"string"}

is_df = pd.read_csv(pasted_path)
print("dataframe created")

# %%
#@title Option 3: Upload CSV from your local file system to Colab
#@markdown (this is temporary while connected to the current Colab runtime session)<br>
#@markdown Run this cell to upload a file
uploaded = files.upload()
for fn in uploaded.keys():
  print("Paste this in the box below:\n/content/{name}".format(name=fn))
# Out:
#      <input type="file" id="files-bea0c5f2-605e-4f13-b206-46f01d8b6d11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bea0c5f2-605e-4f13-b206-46f01d8b6d11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insitu_temp_data_v2021-10-20.csv to insitu_temp_data_v2021-10-20.csv
# Paste this in the box below:
# /content/insitu_temp_data_v2021-10-20.csv

# %%
pasted_path = "/content/insitu_temp_data_v2021-10-20.csv" #@param {type:"string"}

is_df = pd.read_csv(pasted_path)
print("dataframe created")
# Out:
# dataframe created

# %% [markdown]
# ## 6.2 Pair *insitu* data with Landsat data

# %%
#@title Convert local datetime to UTC time
#@markdown __Run this block__ to apply conversion of your specified local time to UTC time. 
insitu_tz = pytz.timezone(insitu_timezone)
landsat_tz = pytz.timezone("UTC")

def convert_datetime(dt, dtformat=datetime_format):
  #converts string format insitu time to a datetime obj
  dto = datetime.strptime(dt, datetime_format)
  #makes it time aware
  dto_local = insitu_tz.localize(dto)
  #converts to utc
  dto_utc = dto_local.astimezone(landsat_tz)
  return dto_utc

dtobj_series = is_df['datetime']
dtobj_series_conv = dtobj_series.apply(convert_datetime)
is_df['datetime_utc'] = dtobj_series_conv

print("\nDate/time function imported and datetime converted in dataframe", strftime("%x %X"))
# Out:
# Date/time function imported and datetime converted in dataframe 09/06/22 21:27:39

# %%
#@markdown Enter the window of time (in minutes) from Landsat flyover where *insitu* data should be included. For example, `timewindow = 30` will include any data within 60 minutes of Landsat flyover (+/- 30 minutes)
timewindow = 30 #@param {type:"number"

cwd = output_dir
os.chdir(cwd)

outfile = (file_prefix + "_temp_landsat_paired.csv")

print(f"Time window: +- {timewindow} minutes")
print(f"In-situ time Zone: {insitu_timezone}")
print("\nLandsat input file:\n", os.path.join(cwd,temp_filename+".csv"))
print("\nOutput file will be saved to:\n", os.path.join(cwd,outfile))

min_sec = timewindow * 60
# Out:
# Time window: +- 30 minutes
# In-situ time Zone: Etc/GMT+5
#
# Landsat input file:
#  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/sunapee_v1_12_temp_stats.csv
#
# Output file will be saved to:
#  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/sunapee_v1_12_temp_landsat_paired.csv

# %%
#@markdown The following codeblock compares the datasets and generate statistics 
#@markdown for in-lake data that matches Landsat flyovers.<br> 
#@markdown It also uses a subfolder called 'ancillary' (and creates the folder if needed) 
#@markdown that keeps a record of any insitu data points that are used for each Landsat scene.
#@markdown If you have a large number of scenes to pair and/or a large dataframe of
#@markdown in-situ data, this step may take some time. Timestamps that print below are 
#@markdown the Landast scene acquisition times where there are in-situ matches.

print("Start:", strftime("%x %X"))
file_name = (output_dir + '/' + temp_filename + '.csv')
gee_csv = pd.read_csv(file_name)
insitu_csv = is_df

#make 'ancillary' folder in defined directory
if not os.path.exists(os.path.join(cwd, 'ancillary')):
    os.makedirs(os.path.join(cwd, 'ancillary'))
print('Matched records files will be visible at ', cwd+ '/ancillary')

#filter GEE output so that it's only as recent as minimum in-situ data
insitumin = min(insitu_csv.datetime_utc)
insitumax = max(insitu_csv.datetime_utc)

def conv_lstime(i):
  return pd.Timestamp(i, unit = 'ms', tz = 'utc')

gee_csv['landsat_time_utc'] = gee_csv.datetime_landsat.apply(conv_lstime)

gee_overlap = gee_csv[gee_csv.landsat_time_utc>insitumin]
gee_overlap_fin = gee_overlap[gee_overlap.landsat_time_utc<insitumax]
#reindex filtered dataset
gee_overlap_fin = gee_overlap_fin.reset_index(drop=True)

gee_datelist = gee_overlap_fin["landsat_time_utc"]

# function to convert dt_delta to seconds
def delta_tosec(i):
  total_secs = i.seconds + i.days*24*60*60
  return total_secs

for i in range(0,len(gee_datelist)):
  scene = gee_overlap_fin['system:index'][i][-20:]
  landsattime = gee_overlap_fin['landsat_time_utc'][i]

  # create a df of insitu data that are observed within the user-specified cutoff 

  #calculate time delta for each obs
  insitu_csv['dt_delta'] = landsattime - insitu_csv['datetime_utc']
  insitu_csv['delta_secs'] = insitu_csv.dt_delta.apply(delta_tosec)  
  same_time = insitu_csv[(abs(insitu_csv.delta_secs) <= min_sec)]
  
  #if the dataframe is not empty, summarize the results
  if same_time.shape[0]>0:
    print(landsattime)
    gee_overlap_fin.loc[i, "scene"] = scene
    gee_overlap_fin.loc[i, "is_temp_avg"] = same_time["temp_degC"].mean()
    gee_overlap_fin.loc[i, "is_temp_stdev"] = same_time["temp_degC"].std()
    gee_overlap_fin.loc[i, "is_depth_avg"] = same_time["depth_m"].mean()
    gee_overlap_fin.loc[i, "is_depth_stdev"] = same_time["depth_m"].std()
    gee_overlap_fin.loc[i, "is_temp_med"] = same_time["temp_degC"].median()
    gee_overlap_fin.loc[i, "insitu_count"] = same_time.shape[0]

    site_stats = same_time.groupby(['location'])['temp_degC'].agg(['median', 'mean', 'std', 'count'])

    sites = site_stats.axes[0]
    stats = site_stats.axes[1]

    for site in sites:
        for stat in stats:
            newcol = "{0}_{1}".format(str(site), str(stat))
            gee_overlap_fin.loc[i, newcol] = site_stats[stat][site].item()

    if same_time.shape[0] > 0:
        same_time.to_csv(os.path.join(cwd, 'ancillary', scene + ".csv"))

out_csv = gee_overlap_fin[gee_overlap_fin["insitu_count"] > 0]
out_csv.to_csv(os.path.join(cwd, outfile))
("Finished:", strftime("%x %X"))
# Out:
# Start: 09/06/22 21:27:46
# Matched records files will be visible at  /content/drive/MyDrive/lakeCoSTR_output/sunapee_v1_12/ancillary
# 2006-07-25 15:26:04.693000+00:00
# 2006-09-11 15:26:38.218000+00:00
# 2007-07-12 15:26:35.703000+00:00
# 2007-08-13 15:26:16.380000+00:00
# 2007-08-29 15:26:05.072000+00:00
# 2007-09-14 15:25:59.297000+00:00
# 2008-05-11 15:21:30.840000+00:00
# 2008-06-12 15:20:39.651000+00:00
# 2008-08-31 15:18:22.672000+00:00
# 2008-10-18 15:16:53.316000+00:00
# 2009-05-30 15:20:55.701000+00:00
# 2009-08-18 15:22:15.552000+00:00
# 2009-09-19 15:22:42.884000+00:00
# 2009-10-21 15:23:03.546000+00:00
# 2009-11-22 15:23:17.660000+00:00
# 2010-06-02 15:23:35.349000+00:00
# 2010-06-18 15:23:31.122000+00:00
# 2010-07-04 15:23:26.405000+00:00
# 2010-09-06 15:23:08.713000+00:00
# 2010-09-22 15:23:03.139000+00:00
# 2010-10-08 15:22:55.004000+00:00
# 2011-06-21 15:22:11.277000+00:00
# 2011-07-07 15:22:05.247000+00:00
# 2011-08-24 15:21:39.563000+00:00
# 2011-10-11 15:20:56.341000+00:00
# 2011-11-12 15:20:26.133000+00:00
# 2006-07-17 15:22:39.882000+00:00
# 2006-08-02 15:22:35.041000+00:00
# 2007-08-05 15:22:59.576000+00:00
# 2007-09-06 15:22:45.709000+00:00
# 2007-09-22 15:22:40.615000+00:00
# 2007-11-25 15:23:05.772000+00:00
# 2008-07-06 15:22:24.003000+00:00
# 2008-08-07 15:22:06.248000+00:00
# 2008-08-23 15:21:59.571000+00:00
# 2008-09-08 15:21:51.720000+00:00
# 2008-09-24 15:21:42.615000+00:00
# 2008-10-10 15:21:29.147000+00:00
# 2008-10-26 15:21:45.683000+00:00
# 2008-11-27 15:22:12.343000+00:00
# 2009-05-22 15:23:20.244000+00:00
# 2010-05-25 15:25:00.761000+00:00
# 2010-07-28 15:25:07.057000+00:00
# 2010-08-29 15:25:09.772000+00:00
# 2010-09-14 15:25:10.984000+00:00
# 2011-05-12 15:26:28.660000+00:00
# 2011-06-29 15:26:24.859000+00:00
# 2011-07-15 15:26:24.881000+00:00
# 2011-07-31 15:26:21.534000+00:00
# 2011-09-01 15:26:15.063000+00:00
# 2011-11-04 15:26:18.886000+00:00
# 2012-06-15 15:27:19.031000+00:00
# 2012-08-02 15:27:51.683000+00:00
# 2012-08-18 15:28:03.843000+00:00
# 2012-09-03 15:28:13.974000+00:00
# 2012-09-19 15:28:21.765000+00:00
# 2012-10-05 15:28:31.496000+00:00
# 2012-11-06 15:28:43.721000+00:00
# 2012-11-22 15:28:52.992000+00:00
# 2013-05-01 15:28:48.413000+00:00
# 2013-05-17 15:28:46.020000+00:00
# 2013-06-02 15:28:36.980000+00:00
# 2013-07-20 15:28:14.576000+00:00
# 2013-08-05 15:28:08.996000+00:00
# 2013-08-21 15:28:15.279000+00:00
# 2013-09-06 15:28:27.023000+00:00
# 2013-10-08 15:28:49.372000+00:00
# 2014-07-07 15:30:25.204000+00:00
# 2014-07-23 15:30:28.429000+00:00
# 2014-08-08 15:30:33.104000+00:00
# 2014-08-24 15:30:30.714000+00:00
# 2014-10-27 15:31:00.161000+00:00
# 2015-05-07 15:32:15.313000+00:00
# 2015-05-23 15:32:21.300000+00:00
# 2015-06-24 15:32:29.826000+00:00
# 2015-07-10 15:32:36.798000+00:00
# 2015-09-12 15:32:48.695000+00:00
# 2015-09-28 15:32:52.108000+00:00
# 2015-10-30 15:33:19.870000+00:00
# 2016-05-25 15:35:21.332000+00:00
# 2016-06-26 15:35:27.585000+00:00
# 2016-07-12 15:35:26.605000+00:00
# 2016-08-29 15:35:34.561000+00:00
# 2016-09-14 15:35:36.298000+00:00
# 2017-07-15 15:35:33.389000+00:00
# 2017-07-31 15:35:32.090000+00:00
# 2017-09-01 15:35:30.481000+00:00
# 2017-09-17 15:35:28.075000+00:00
# 2017-10-03 15:35:29.573000+00:00
# 2017-11-04 15:35:31.414000+00:00
# 2018-05-31 15:32:51.477000+00:00
# 2018-07-02 15:32:15.711000+00:00
# 2018-07-18 15:31:57.797000+00:00
# 2018-08-19 15:31:22.672000+00:00
# 2018-09-04 15:31:02.812000+00:00
# 2018-10-22 15:29:55.725000+00:00
# 2018-11-07 15:29:34.934000+00:00
# 2019-05-18 15:23:29.855000+00:00
# 2019-06-03 15:22:55.492000+00:00
# 2019-07-05 15:21:44.531000+00:00
# 2019-08-06 15:20:27.959000+00:00
# 2019-08-22 15:19:47.761000+00:00
# 2019-09-07 15:19:06.333000+00:00
# 2019-10-09 15:17:44.116000+00:00
# 2020-05-20 15:06:03.964000+00:00
# 2020-06-21 15:04:11.160000+00:00
# 2020-08-24 15:00:13.173000+00:00
# 2020-09-09 14:59:10.306000+00:00
# 2020-09-25 14:58:06.948000+00:00
# 2020-10-11 14:57:06.072000+00:00
# 2013-09-30 15:34:46.433000+00:00
# 2014-06-29 15:32:38.509000+00:00
# 2014-09-01 15:32:59.911000+00:00
# 2014-09-17 15:33:01.558000+00:00
# 2014-10-03 15:33:04.481000+00:00
# 2014-11-20 15:33:02.885000+00:00
# 2015-07-02 15:32:18.313000+00:00
# 2015-08-03 15:32:31.019000+00:00
# 2015-08-19 15:32:38.478000+00:00
# 2015-11-23 15:33:02.762000+00:00
# 2016-06-18 15:32:36.899000+00:00
# 2016-07-04 15:32:46.324000+00:00
# 2016-07-20 15:32:52.539000+00:00
# 2016-08-05 15:32:55.320000+00:00
# 2016-09-22 15:33:07.849000+00:00
# 2016-10-24 15:33:14.718000+00:00
# 2017-05-04 15:32:11.387000+00:00
# 2017-06-21 15:32:38.099000+00:00
# 2017-07-23 15:32:47.646000+00:00
# 2017-08-24 15:32:58.898000+00:00
# 2017-09-25 15:33:05.620000+00:00
# 2017-11-12 15:33:09.357000+00:00
# 2017-11-28 15:33:02.865000+00:00
# 2018-05-23 15:31:48.135000+00:00
# 2018-07-10 15:32:01.766000+00:00
# 2018-08-27 15:32:25.308000+00:00
# 2018-10-14 15:32:43.859000+00:00
# 2019-05-26 15:32:34.573000+00:00
# 2019-06-27 15:32:47.056000+00:00
# 2019-07-13 15:32:50.218000+00:00
# 2019-07-29 15:32:55.848000+00:00
# 2019-08-14 15:33:01.618000+00:00
# 2019-08-30 15:33:05.436000+00:00
# 2019-09-15 15:33:10.368000+00:00
# 2019-11-02 15:33:16.982000+00:00
# 2020-07-15 15:32:46.161000+00:00
# 2020-07-31 15:32:50.485000+00:00
# 2020-09-17 15:33:09.206000+00:00
# ('Finished:', '09/06/22 21:41:02')

# %% [markdown]
# ##You are all set. Go analyze your lake surface temperature data!
#
# We suggest you save a copy of this notebook in the same folder as your downloaded data, which will appear in your Google Drive in the 'lakeCoSTR_output' folder for good measure.
